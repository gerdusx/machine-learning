# %%
import pandas as pd

# %%
filename = 'amazon_baby.csv'

# %%
products = pd.read_csv(filename)

# %%
products.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183531 entries, 0 to 183530
# Data columns (total 3 columns):
# name      183213 non-null object
# review    182702 non-null object
# rating    183531 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 105.2 MB

# %%
products.tail()
# Out:
#                                                      name  \
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5

# %%
products['sentiment'] = products['rating'] >= 4

# %%
selected_words = ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 'terrible', 'awful', 'wow', 'hate']

# %%
testreview = products.iloc[5]['review']

# %%
import spacy
spacy_nlp = spacy.load('en_core_web_sm')

# %%
products
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  sentiment
# 0       These flannel wipes are OK, but in my opinion ...       3      False
# 1       it came early and was not disappointed. i love...       5       True
# 2       Very soft and comfortable and warmer than it l...       5       True
# 3       This is a product well worth the purchase.  I ...       5       True
# 4       All of my kids have cried non-stop when I trie...       5       True
# ...                                                   ...     ...        ...
# 183526  Such a great idea! very handy to have and look...       5       True
# 183527  This product rocks!  It is a great blend of fu...       5       True
# 183528  This item looks great and cool for my kids.......       5       True
# 183529  I am extremely happy with this product. I have...       5       True
# 183530  I love this product very mush . I have bought ...       5       True
#
# [183531 rows x 4 columns]

# %%
def get_count_awesome(review):
    count = 0;
    if isinstance(review, str):
        doc = spacy_nlp(review)
        tokens = [token.text for token in doc]
        count = tokens.count('awesome')

    return count

# %%
products['awesome'] = products['review'].apply(get_count_awesome)
print('done')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-fd793015f62b> in <module>
# ----> 1 products['awesome'] = products['review'].apply(get_count_awesome)
#       2 print('done')
#
# ~/venv/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-41-1b282639e0d5> in get_count_awesome(review)
#       2     count = 0;
#       3     if isinstance(review, str):
# ----> 4         doc = spacy_nlp(review)
#       5         tokens = [token.text for token in doc]
#       6         count = tokens.count('awesome')
#
# ~/venv/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     433             if not hasattr(proc, "__call__"):
#     434                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 435             doc = proc(doc, **component_cfg.get(name, {}))
#     436             if doc is None:
#     437                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     131
#     132     def predict(self, X):
# --> 133         y, _ = self.begin_update(X, drop=None)
#     134         return y
#     135
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/venv/lib/python3.6/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/venv/lib/python3.6/site-packages/thinc/api.py in uniqued_fwd(X, drop)
#     377         )
#     378         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
# --> 379         Y_uniq, bp_Y_uniq = layer.begin_update(X_uniq, drop=drop)
#     380         Y = Y_uniq[inv].reshape((X.shape[0],) + Y_uniq.shape[1:])
#     381
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      58     def begin_update(self, X, drop=0.0):
#      59         if self.child is not None:
# ---> 60             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      61         else:
#      62             backprop_child = None
#
# ~/venv/lib/python3.6/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
products
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  sentiment
# 0       These flannel wipes are OK, but in my opinion ...       3      False
# 1       it came early and was not disappointed. i love...       5       True
# 2       Very soft and comfortable and warmer than it l...       5       True
# 3       This is a product well worth the purchase.  I ...       5       True
# 4       All of my kids have cried non-stop when I trie...       5       True
# ...                                                   ...     ...        ...
# 183526  Such a great idea! very handy to have and look...       5       True
# 183527  This product rocks!  It is a great blend of fu...       5       True
# 183528  This item looks great and cool for my kids.......       5       True
# 183529  I am extremely happy with this product. I have...       5       True
# 183530  I love this product very mush . I have bought ...       5       True
#
# [183531 rows x 4 columns]
